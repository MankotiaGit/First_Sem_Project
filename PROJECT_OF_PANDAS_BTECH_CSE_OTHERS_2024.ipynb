# %% [markdown]
# <a href="https://colab.research.google.com/github/MankotiaGit/First_Sem_Project/blob/main/PROJECT_OF_PANDAS_BTECH_CSE_OTHERS_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA TITANIC/TRAIN TITANIC.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#how big is the data
df.shape
# Out:
# (891, 12)

# %%
#how does the data look like
df.sample(6)
# Out:
#      PassengerId  Survived  Pclass  \
# 394          395         1       3
# 331          332         0       1
# 877          878         0       3
# 659          660         0       1
# 19            20         1       3
# 742          743         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 331                                Partner, Mr. Austen    male  45.5      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 659                         Newell, Mr. Arthur Webster    male  58.0      0
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
#
#      Parch    Ticket      Fare            Cabin Embarked
# 394      2   PP 9549   16.7000               G6        S
# 331      0    113043   28.5000             C124        S
# ...

# %%
#find top five rows
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
#find rows from bottom
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#find the data type of column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#how does the data look like mathematically
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#are there any missing value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# are there any duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
#find ht coorelation between the column
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#find the columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId', 'Name', 'Pclass', 'Survived']]
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
#      Survived
# 0           0
# 1           1
# ...

# %%
#indexing and slicing
df.iloc[0:5, 0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.loc[0:5, ['PassengerId', 'Survived', 'Pclass', 'Name']]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James

# %%
df[100:110]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 100          101         0       3           Petranec, Miss. Matilda  female
# 101          102         0       3  Petroff, Mr. Pastcho ("Pentcho")    male
# 102          103         0       1         White, Mr. Richard Frasar    male
# 103          104         0       3        Johansson, Mr. Gustaf Joel    male
# 104          105         0       3    Gustafsson, Mr. Anders Vilhelm    male
# 105          106         0       3             Mionoff, Mr. Stoytcho    male
# 106          107         1       3  Salkjelsvik, Miss. Anna Kristine  female
# 107          108         1       3            Moss, Mr. Albert Johan    male
# 108          109         0       3                   Rekic, Mr. Tido    male
# 109          110         1       3               Moran, Miss. Bertha  female
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 100  28.0      0      0   349245   7.8958   NaN        S
# ...

# %%
df.sort_values("Age", ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(["Age", "Fare"], ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 755          756         1       2
# 469          470         1       3
# 644          645         1       3
# 831          832         1       2
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 803                    Thomas, Master. Assad Alexander    male  0.42      0
# 755                          Hamalainen, Master. Viljo    male  0.67      1
# 469                      Baclini, Miss. Helene Barbara  female  0.75      2
# 644                             Baclini, Miss. Eugenie  female  0.75      2
# 831                    Richards, Master. George Sibley    male  0.83      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].nunique()
# Out:
# 3

# %%
#how to drop null value
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 1    158
# 2     15
# 3     10
# Name: count, dtype: int64

# %%
df["Embarked"].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
import seaborn as sns
sns.countplot(df["Embarked"])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
#piechart
df["Sex"].value_counts()
# Out:
# Sex
# male      95
# female    88
# Name: count, dtype: int64

# %%
df["Sex"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sex"].value_counts().plot(kind="pie", autopct = "%1.0f%%")
# Out:
# <Axes: ylabel='count'>

# %%
#Histogram
import matplotlib.pyplot as plt
plt.hist(df["Age"], bins = 6)
# Out:
# (array([12., 46., 60., 40., 22.,  3.]),
#  array([ 0.92, 14.1 , 27.28, 40.46, 53.64, 66.82, 80.  ]),
#  <BarContainer object of 6 artists>)

# %%
import numpy as np
cgpa =[6, 6.8, 7, 7.5, 8, 8.5, 9, 9.5, 10]
package = [5, 6, 7, 8, 9, 12, 15, 17, 20]
cgpa = np.array(cgpa)
package = np.array(package)
font1 = {"family":"serif", "color":"blue", "size":20}
font2 = {"family":"serif", "color":"darkred", "size":15}
plt.title("Data of Shoolini University", fontdict = font1)
plt.xlabel("cgpa", fontdict = font2)
plt.ylabel("package", fontdict = font2)

plt.plot(cgpa, package, "*:g", ms = 20, mec = "r", mfc = "b")
plt.grid()
plt.show()

# %%
fruit = np.array(["apple","banana","mango","orange"])
fruit_number = np.array([10, 15, 20, 25])
plt.title("Fruits Data")
plt.xlabel("Fruit")
plt.ylabel(" Fruits Number")
color = ["Red", "Yellow", "Pink", "Orange"]
plt.bar(fruit, fruit_number, color = color)
plt.show()

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips

# %%
tips.columns

# %%
sns.boxplot(tips["total_bill"])

# %%
tips.columns

# %%
sns.boxplot(tips, x = "tip", y = "sex")

# %%
sns.scatterplot(tips, x = "total_bill", y = "tip" , hue = "sex")

# %%
sns.barplot(tips, x = "sex", y = "tip", hue = "smoker")
